# %%
import h5py
import numpy as np    
f1 = h5py.File("/mnt/share-private/ALC_ptychography_alignment/pty_tomo_NX.h5",'r')

# %%
print(f1['entry1']['tomo_entry']['data']['data'])
# Out:
# <HDF5 dataset "data": shape (1000, 2217, 3097), type "<f4">
