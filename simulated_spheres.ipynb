# %%
from cil.utilities import dataexample
# Load data
ground_truth = dataexample.SIMULATED_SPHERE_VOLUME.get()

# %%
ground_truth.as_array().shape
# Out:
# (128, 128, 128)

# %%
from cil.utilities.display import show2D

# %%
show2D(ground_truth, slice_list=[50,80], origin = 'upper', num_cols = 2)

# %%
import numpy as np

# %%
np.save( "simulated_spheres_128.npy", ground_truth.as_array())

# %%
reloaded = np.load("simulated_spheres_128.npy")

# %%
show2D(reloaded)
