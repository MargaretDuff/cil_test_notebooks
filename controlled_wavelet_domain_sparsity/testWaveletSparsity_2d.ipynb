# %%
#
#   Authored by:    Tommi Heikkilä (LUT)

import cil
print(f"Using CIL version {cil.__version__}")
# Out:
# Using CIL version 24.1.0

# %% [markdown]
# # Controlled Wavelet Sparsity using callbacks
#
# ### 2D laboratory micro-CT, fan-beam data of a walnut

# %% [markdown]
# This example requires the dataset `Data328.mat` from https://doi.org/10.5281/zenodo.1254206 :
#
# - https://zenodo.org/records/1254206/files/Data328.mat?download=1
#
# If running locally please download the data and update the 'path' variable below.

# %%
path = './data'

# %%
# remove some annoying warnings
import logging
logger = logging.getLogger('dxchange')
logger.setLevel(logging.ERROR)

# %% [markdown]
# First import all of the modules we will need:

# %%
import os
import numpy as np

# cil imports
from cil.framework import ImageData, ImageGeometry
from cil.framework import AcquisitionGeometry, AcquisitionData

from cil.optimisation.functions import LeastSquares, L1Sparsity, ScaledFunction
from cil.optimisation.operators import WaveletOperator
from cil.optimisation.algorithms import FISTA

from cil.plugins.astra import ProjectionOperator

from cil.utilities.display import show2D, show_geometry

import scipy.io

# %% [markdown]
# Load the 2D fan-beam sinogram of walnut:

# %%
filename = os.path.join(path, "Data328.mat")

matdata = scipy.io.loadmat(filename)
sinogram = matdata["m"].transpose()
num_angles, num_pixels = sinogram.shape

# %% [markdown]
# ## Create geometry
#
# We have to manually set the values for the correct geometry. These can be found in the [documentation](https://arxiv.org/abs/1502.04064) of the data.

# %%
# Acquisition geometry parameters
SOD = 110 # Source-Origin-distance
print(f'SOD: {SOD:.3f} mm')
SDD = 300 # Source-Detector-distance
print(f'SDD: {SDD:.3f} mm')
ODD = SDD - SOD # Origin-detector-distance
print(f'ODD: {ODD:.3f} mm')
pixelSize = 114.8 / num_pixels # Detector pixel width after binning
print(f'Detector pixel size: {pixelSize:.3f} mm')

angles = np.linspace(0., 360., 120, endpoint=False)
# Out:
# SOD: 110.000 mm
# SDD: 300.000 mm
# ODD: 190.000 mm
# Detector pixel size: 0.350 mm

# %%
ag = AcquisitionGeometry.create_Cone2D([0,-SOD], [0,ODD], units='mm',detector_direction_x=[1, 0])
ag.set_panel(num_pixels, pixel_size=pixelSize, origin='bottom-left')
ag.set_angles(-angles)
ag.set_labels(('angle','horizontal'))
print(ag)
# Out:
# 2D Cone-beam tomography
# System configuration:
# 	Source position: [   0., -110.]
# 	Rotation axis position: [0., 0.]
# 	Detector position: [  0., 190.]
# 	Detector direction x: [1., 0.]
# Panel configuration:
# 	Number of pixels: [328   1]
# 	Pixel size: [0.35 0.35]
# 	Pixel origin: bottom-left
# Channel configuration:
# 	Number of channels: 1
# Acquisition description:
# 	Number of positions: 120
# 	Angles 0-9 in degrees: [ -0.,  -3.,  -6.,  -9., -12., -15., -18., -21., -24., -27.]
# 	Angles 110-119 in degrees: [-330., -333., -336., -339., -342., -345., -348., -351., -354., -357.]
# 	Full angular array can be accessed with acquisition_data.geometry.angles
# Distances in units: mm

# %%
show_geometry(ag);

# %% [markdown]
# ### Image geometry and data
#
# Notice in particular how the `voxel_size` (or image pixel size) matches the reported value of 0.128 mm.

# %%
# Setup image geometry
n = num_pixels - 1
ig = ag.get_ImageGeometry()
ig.voxel_num_x = n
ig.voxel_num_y = n
print(ig)

# Setup data
data = AcquisitionData(sinogram, deep_copy=False, geometry=ag)
show2D(data);
# Out:
# Number of channels: 1
# channel_spacing: 1.0
# voxel_num : x327,y327
# voxel_size : x0.12833333333333333,y0.12833333333333333
# center : x0,y0

# %% [markdown]
# ## Reconstructions

# %%
A = ProjectionOperator(ig, ag, 'cpu')
Anorm = A.norm()
# Normalize
A = 1/Anorm*A
data = 1/Anorm*data

x_bp = A.adjoint(data) # Simple backprojection
show2D(x_bp, size=(10,10), title="Naive backprojection");

# %% [markdown]
# ### Wavelet transform

# %%
wname = 'db2'
level = 4

W = WaveletOperator(ig, level=level, wname=wname)

# %% [markdown]
# ### Fast Iterative Soft Thresholding Algorithm (FISTA)

# %%
f = LeastSquares(A, data)
g = L1Sparsity(W)

tau = 1e-5  # Regularization parameter

fista = FISTA(initial=ig.allocate(0), f=f, g=tau*g, )

# %%
fista.run(50)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
x_fista = fista.get_output()
show2D(x_fista, size=(10,10), fix_range=(0,0.08), title=f"FISTA with {tau = }");

# %% [markdown]
# Looks okay but how do we know the choice of regularization parameter was good? Could we get a better result with another value? Do we have the patience to try out dozens or even hundreds of values?

# %% [markdown]
# ## Automated Controlled Sparsity
#
# We follow the automated tuning strategy as introduced in
# > Purisha, Z., Rimpeläinen, J., Bubba, T., & Siltanen, S. (2017).
# *Controlled wavelet domain sparsity for x-ray tomography*.
# Measurement Science and Technology, 29(1), 014002.
# [DOI:10.1088/1361-6501/aa9260](https://doi.org/10.1088/1361-6501/aa9260)
#
# We'll try to implement it as a `StepSizeRule` and `callback`. However we are NOT actually changing the `step_size` (which is based on the Lipschitz constant of the data mistmatch term) but the regularization parameter `tau`. But we can update it every iterate by using `StepSizeRule` (in fact we could pass it an actual `StepSizeRule` to perform but let's just stick with constant value for now)

# %%
from cil.optimisation.utilities import callbacks
from cil.optimisation.utilities.StepSizeMethods import StepSizeRule

# %%
class ControlledSparsity(StepSizeRule):
    """Controlled (Wavelet Domains) Sparsity update rule.
    This only changes the regularization parameter for function `g`, NOT the step size! 
    The stopping criterion is given by `DesiredSparsity` callback.
    
    Reference
    ---------
        "Controlled wavelet domain sparsity for X-ray tomography" (2017), Purisha et al.  
        DOI:10.1088/1361-6501/aa9260
    """
    def __init__(self, desired_sparsity, step_weight=0.2, tol = 1e-8, print_stuff=0):
        """Initialize the Controlled (Wavelet Domains) Sparsity update rule."""
        self.tau = None
        self.step_size = None
        self.dif_sparsity = 1
        self.sparsity_vals = []
        self.reg_param_vals = []
        self.desired_sparsity = desired_sparsity # C_pr
        # These follow the notation from the article
        self.beta = step_weight
        self.kappa = tol
        # Print update on sparsity
        self.print_stuff = print_stuff
        self.W = None
        self.Wlen = None

    def get_step_size(self, algorithm):
        """Tune the regularization parameter (and hence the regularization parameter) using the sparsity of the current iterate"""
        g = algorithm.g
        if g.__class__ is not ScaledFunction:
            g = ScaledFunction(g, 1.0)
        self.tau = g.scalar
        regFun = g.function
        if not regFun.__class__ is L1Sparsity:
            raise TypeError(
                "The method does not necessarily make sense with regularizatio methods other than `L1Sparsity`!"
            )
        
        if self.W is None: # Get this operator if needed
            self.W = regFun.Q # Orthogonal operator, i.e. the wavelet transform
        if self.Wlen is None: # Get this value if needed
            self.Wlen = self._getWlen(W) # Normalization factor to get the ratio of "nonzero" coefficients
        if self.step_size is None: # Get this value if needed
            self.step_size = algorithm._calculate_default_step_size() # This actually never changes!

        Wx = self.W.direct(algorithm.get_output())
        sparsity = self._computeSparsity(Wx)
        self.sparsity_vals.append(sparsity)

        # Previous difference in sparsity
        dif_old = self.dif_sparsity
        # Current difference in sparsity
        dif = sparsity - self.desired_sparsity
        self.dif_sparsity = dif

        # If the sign changes, we have passed the desired sparsity -> smaller steps needed
        if np.sign(dif) != np.sign(dif_old):
            self.beta = self.beta*(1-np.minimum(0.99, np.abs(dif - dif_old)))

        # Update regularization parameter
        self.tau = np.maximum(0, self.tau + self.beta*dif)
        self.reg_param_vals.append(self.tau)

        if self.print_stuff > 0:
            print(f"Iteration : {algorithm.iterations[-1]} | Current sparsity: {sparsity:.3f} | Regularization param.: {self.tau:.2e} | Desired sparsity: {self.desired_sparsity:.3f} | Difference: {dif:.3f}") 

        # Here we update the regularization parameter `tau`
        g.scalar = self.tau
        algorithm.g = g
        # Return the same step size as before
        return self.step_size

    def _getWlen(self, W):
        '''Helper function to get the total number of wavelet coefficients (without the added zeros)'''
        ndim = W.domain_geometry().ndim
        shapes = W._shapes
        wLen = np.prod(shapes[0]) # Number of Approximation Coefficients
        for l in range(W.level):
            wLen += (2**ndim - 1)*np.prod(shapes[l+1][ndim*'d']) # Number of Detail Coefficients for level ´l´
        return wLen
    
    def _computeSparsity(self, Wx):
        '''Compute the number of "large" or "meaningful" coefficients given their magnitude'''
        return (Wx.abs().as_array() > self.kappa).sum() / self.Wlen

# %%
class DesiredSparsity(callbacks.Callback):
    """"Desired sparsity stopping rule, to halt the iteration when the desired sparsity
    level has been reached AND the relative change between consecutive iterates is small enough.4
    This way the iterates have time to converge to the right regularization parameter value.
    
    Reference
    ---------
        "Controlled wavelet domain sparsity for X-ray tomography" (2017), Purisha et al.  
        DOI:10.1088/1361-6501/aa9260
    """
    def __init__(self, spar_tol=5e-3, rel_change_tol=1e-4, print_stuff=1, print_skip=5):
        self.sparsity_controller = None
        self.spar_tol = spar_tol # Sparsity tolerance
        self.rel_change_tol = rel_change_tol # Rel. change tolerance
        # Some values are still unknown
        self.x_old = -100.0 # Bogus value
        self.desired_sparsity = None
        self.current_sparsity = np.nan
        self.rel_change = np.inf
        # Print update on sparsity
        self.print_stuff = print_stuff
        self.print_skip = print_skip

    def __call__(self, algorithm):
        """Compute the latest sparsity difference and relative change"""
        iter = algorithm.iterations[-1] # Current iteration
        if self.sparsity_controller is None:
            self.sparsity_controller = algorithm.step_size_rule
        if self.desired_sparsity is None:
            self.desired_sparsity = self.sparsity_controller.desired_sparsity
        if iter < 0:
            return # Skip the first iterate
        self.current_sparsity = self.sparsity_controller.sparsity_vals[iter-1]

        # Difference in sparsity
        dif = self.current_sparsity - self.desired_sparsity
        self.dif_sparsity = dif

        self.rel_change = (algorithm.get_output() - self.x_old).norm()
        self.x_old = algorithm.get_output()

        # Print current status
        if iter % self.print_skip == 0:
            if self.print_stuff > 0:
                tau = algorithm.step_size_rule.tau
                print(f"Iteration : {iter} | Current sparsity: {self.current_sparsity:.3f} | Regularization param.: {tau:.2e} | Desired sparsity: {self.desired_sparsity:.3f} | Difference: {dif:.3f}", end='')
            if self.print_stuff > 1:
                beta = algorithm.step_size_rule.beta
                print(f" | Beta: {beta:.2e} | Relative change: {self.rel_change / self.x_old.norm():.2e}", end='')
            if self.print_stuff > 0:
                print("") # Line break
        
            
        # Check if current sparsity within tolerance
        if (np.abs(dif) < self.spar_tol) and self.rel_change < self.rel_change_tol*self.x_old.norm():
            print(f"Desired sparsity reached after {iter} iterations!")
            raise StopIteration

# %%
reg_weight = 1e-2
# Automated tuning of regularization parameter
sparsity_ctrl = ControlledSparsity(desired_sparsity=0.3)
fista_controlled = FISTA(initial=ig.allocate(0), f=f, g=reg_weight*g, step_size=sparsity_ctrl, max_iteration=500)

# %%
# Sparsity based stopping rule
sparsity_stop = DesiredSparsity(print_stuff=2, rel_change_tol=5e-4)

# %%
fista_controlled.run(500, callbacks=[sparsity_stop])
# Out:
# Iteration : 5 | Current sparsity: 0.031 | Regularization param.: 7.25e-03 | Desired sparsity: 0.300 | Difference: -0.269 | Beta: 2.00e-03 | Relative change: 8.76e-02
# Iteration : 10 | Current sparsity: 0.028 | Regularization param.: 4.54e-03 | Desired sparsity: 0.300 | Difference: -0.272 | Beta: 2.00e-03 | Relative change: 4.76e-02
# Iteration : 15 | Current sparsity: 0.028 | Regularization param.: 1.81e-03 | Desired sparsity: 0.300 | Difference: -0.272 | Beta: 2.00e-03 | Relative change: 2.82e-02
# Iteration : 20 | Current sparsity: 1.000 | Regularization param.: 1.06e-04 | Desired sparsity: 0.300 | Difference: 0.700 | Beta: 1.51e-04 | Relative change: 2.78e-02
# Iteration : 25 | Current sparsity: 0.161 | Regularization param.: 8.52e-05 | Desired sparsity: 0.300 | Difference: -0.139 | Beta: 1.21e-04 | Relative change: 2.58e-02
# Iteration : 30 | Current sparsity: 0.293 | Regularization param.: 4.26e-05 | Desired sparsity: 0.300 | Difference: -0.007 | Beta: 1.21e-04 | Relative change: 1.97e-02
# Iteration : 35 | Current sparsity: 0.301 | Regularization param.: 4.27e-05 | Desired sparsity: 0.300 | Difference: 0.001 | Beta: 1.21e-04 | Relative change: 1.32e-02
# Iteration : 40 | Current sparsity: 0.297 | Regularization param.: 4.15e-05 | Desired sparsity: 0.300 | Difference: -0.003 | Beta: 1.21e-04 | Relative change: 9.36e-03
# Iteration : 45 | Current sparsity: 0.296 | Regularization param.: 3.93e-05 | Desired sparsity: 0.300 | Difference: -0.004 | Beta: 1.21e-04 | Relative change: 7.96e-03
# Iteration : 50 | Current sparsity: 0.298 | Regularization param.: 3.75e-05 | Desired sparsity: 0.300 | Difference: -0.002 | Beta: 1.21e-04 | Relative change: 6.90e-03
# Iteration : 55 | Current sparsity: 0.298 | Regularization param.: 3.62e-05 | Desired sparsity: 0.300 | Difference: -0.002 | Beta: 1.21e-04 | Relative change: 5.69e-03
# Iteration : 60 | Current sparsity: 0.298 | Regularization param.: 3.49e-05 | Desired sparsity: 0.300 | Difference: -0.002 | Beta: 1.21e-04 | Relative change: 4.74e-03
# Iteration : 65 | Current sparsity: 0.298 | Regularization param.: 3.36e-05 | Desired sparsity: 0.300 | Difference: -0.002 | Beta: 1.21e-04 | Relative change: 4.18e-03
# Iteration : 70 | Current sparsity: 0.298 | Regularization param.: 3.25e-05 | Desired sparsity: 0.300 | Difference: -0.002 | Beta: 1.21e-04 | Relative change: 3.75e-03
# Iteration : 75 | Current sparsity: 0.299 | Regularization param.: 3.16e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 3.28e-03
# Iteration : 80 | Current sparsity: 0.298 | Regularization param.: 3.07e-05 | Desired sparsity: 0.300 | Difference: -0.002 | Beta: 1.21e-04 | Relative change: 2.88e-03
# Iteration : 85 | Current sparsity: 0.299 | Regularization param.: 2.99e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 2.63e-03
# Iteration : 90 | Current sparsity: 0.299 | Regularization param.: 2.93e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 2.45e-03
# Iteration : 95 | Current sparsity: 0.299 | Regularization param.: 2.89e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 2.26e-03
# Iteration : 100 | Current sparsity: 0.299 | Regularization param.: 2.84e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 2.07e-03
# Iteration : 105 | Current sparsity: 0.299 | Regularization param.: 2.77e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.93e-03
# Iteration : 110 | Current sparsity: 0.299 | Regularization param.: 2.72e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.84e-03
# Iteration : 115 | Current sparsity: 0.299 | Regularization param.: 2.66e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.75e-03
# Iteration : 120 | Current sparsity: 0.299 | Regularization param.: 2.63e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.67e-03
# Iteration : 125 | Current sparsity: 0.299 | Regularization param.: 2.59e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.60e-03
# Iteration : 130 | Current sparsity: 0.300 | Regularization param.: 2.55e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.55e-03
# Iteration : 135 | Current sparsity: 0.299 | Regularization param.: 2.51e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.50e-03
# Iteration : 140 | Current sparsity: 0.299 | Regularization param.: 2.48e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.46e-03
# Iteration : 145 | Current sparsity: 0.300 | Regularization param.: 2.46e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.42e-03
# Iteration : 150 | Current sparsity: 0.300 | Regularization param.: 2.43e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.39e-03
# Iteration : 155 | Current sparsity: 0.299 | Regularization param.: 2.40e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.36e-03
# Iteration : 160 | Current sparsity: 0.300 | Regularization param.: 2.38e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.33e-03
# Iteration : 165 | Current sparsity: 0.300 | Regularization param.: 2.36e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.31e-03
# Iteration : 170 | Current sparsity: 0.299 | Regularization param.: 2.34e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.21e-04 | Relative change: 1.28e-03
# Iteration : 175 | Current sparsity: 0.300 | Regularization param.: 2.33e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.26e-03
# Iteration : 180 | Current sparsity: 0.300 | Regularization param.: 2.32e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.23e-03
# Iteration : 185 | Current sparsity: 0.300 | Regularization param.: 2.30e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.21e-03
# Iteration : 190 | Current sparsity: 0.300 | Regularization param.: 2.29e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.19e-03
# Iteration : 195 | Current sparsity: 0.300 | Regularization param.: 2.28e-05 | Desired sparsity: 0.300 | Difference: 0.000 | Beta: 1.21e-04 | Relative change: 1.17e-03
# Iteration : 200 | Current sparsity: 0.300 | Regularization param.: 2.27e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.14e-03
# Iteration : 205 | Current sparsity: 0.300 | Regularization param.: 2.26e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.12e-03
# Iteration : 210 | Current sparsity: 0.300 | Regularization param.: 2.25e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.21e-04 | Relative change: 1.10e-03
# Iteration : 215 | Current sparsity: 0.300 | Regularization param.: 2.23e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 1.08e-03
# Iteration : 220 | Current sparsity: 0.300 | Regularization param.: 2.23e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 1.06e-03
# Iteration : 225 | Current sparsity: 0.300 | Regularization param.: 2.22e-05 | Desired sparsity: 0.300 | Difference: 0.000 | Beta: 1.20e-04 | Relative change: 1.04e-03
# Iteration : 230 | Current sparsity: 0.300 | Regularization param.: 2.20e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 1.03e-03
# Iteration : 235 | Current sparsity: 0.300 | Regularization param.: 2.20e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 1.01e-03
# Iteration : 240 | Current sparsity: 0.300 | Regularization param.: 2.19e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 9.89e-04
# Iteration : 245 | Current sparsity: 0.300 | Regularization param.: 2.18e-05 | Desired sparsity: 0.300 | Difference: 0.000 | Beta: 1.20e-04 | Relative change: 9.72e-04
# Iteration : 250 | Current sparsity: 0.299 | Regularization param.: 2.16e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.20e-04 | Relative change: 9.54e-04
# Iteration : 255 | Current sparsity: 0.300 | Regularization param.: 2.16e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 9.38e-04
# Iteration : 260 | Current sparsity: 0.300 | Regularization param.: 2.15e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 9.22e-04
# Iteration : 265 | Current sparsity: 0.300 | Regularization param.: 2.14e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 9.07e-04
# Iteration : 270 | Current sparsity: 0.300 | Regularization param.: 2.13e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.20e-04 | Relative change: 8.93e-04
# Iteration : 275 | Current sparsity: 0.300 | Regularization param.: 2.12e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 8.79e-04
# Iteration : 280 | Current sparsity: 0.300 | Regularization param.: 2.12e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 8.64e-04
# Iteration : 285 | Current sparsity: 0.300 | Regularization param.: 2.11e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 8.49e-04
# Iteration : 290 | Current sparsity: 0.300 | Regularization param.: 2.11e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 8.33e-04
# Iteration : 295 | Current sparsity: 0.300 | Regularization param.: 2.10e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 8.18e-04
# Iteration : 300 | Current sparsity: 0.300 | Regularization param.: 2.09e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 8.04e-04
# Iteration : 305 | Current sparsity: 0.300 | Regularization param.: 2.09e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 7.89e-04
# Iteration : 310 | Current sparsity: 0.300 | Regularization param.: 2.08e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 7.74e-04
# Iteration : 315 | Current sparsity: 0.300 | Regularization param.: 2.08e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 7.59e-04
# Iteration : 320 | Current sparsity: 0.300 | Regularization param.: 2.07e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 7.45e-04
# Iteration : 325 | Current sparsity: 0.300 | Regularization param.: 2.07e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 7.32e-04
# Iteration : 330 | Current sparsity: 0.300 | Regularization param.: 2.06e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.19e-04 | Relative change: 7.18e-04
# Iteration : 335 | Current sparsity: 0.301 | Regularization param.: 2.06e-05 | Desired sparsity: 0.300 | Difference: 0.001 | Beta: 1.18e-04 | Relative change: 7.04e-04
# Iteration : 340 | Current sparsity: 0.300 | Regularization param.: 2.06e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.90e-04
# Iteration : 345 | Current sparsity: 0.300 | Regularization param.: 2.05e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.78e-04
# Iteration : 350 | Current sparsity: 0.300 | Regularization param.: 2.05e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.66e-04
# Iteration : 355 | Current sparsity: 0.300 | Regularization param.: 2.04e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.56e-04
# Iteration : 360 | Current sparsity: 0.300 | Regularization param.: 2.04e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.44e-04
# Iteration : 365 | Current sparsity: 0.300 | Regularization param.: 2.03e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.33e-04
# Iteration : 370 | Current sparsity: 0.300 | Regularization param.: 2.03e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.21e-04
# Iteration : 375 | Current sparsity: 0.300 | Regularization param.: 2.03e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 6.10e-04
# Iteration : 380 | Current sparsity: 0.300 | Regularization param.: 2.02e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.18e-04 | Relative change: 5.99e-04
# Iteration : 385 | Current sparsity: 0.300 | Regularization param.: 2.02e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.87e-04
# Iteration : 390 | Current sparsity: 0.300 | Regularization param.: 2.01e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.77e-04
# Iteration : 395 | Current sparsity: 0.299 | Regularization param.: 2.00e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.17e-04 | Relative change: 5.69e-04
# Iteration : 400 | Current sparsity: 0.300 | Regularization param.: 2.01e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.60e-04
# Iteration : 405 | Current sparsity: 0.299 | Regularization param.: 2.00e-05 | Desired sparsity: 0.300 | Difference: -0.001 | Beta: 1.17e-04 | Relative change: 5.51e-04
# Iteration : 410 | Current sparsity: 0.300 | Regularization param.: 2.00e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.43e-04
# Iteration : 415 | Current sparsity: 0.300 | Regularization param.: 2.00e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.34e-04
# Iteration : 420 | Current sparsity: 0.300 | Regularization param.: 1.99e-05 | Desired sparsity: 0.300 | Difference: 0.000 | Beta: 1.17e-04 | Relative change: 5.27e-04
# Iteration : 425 | Current sparsity: 0.300 | Regularization param.: 1.99e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.19e-04
# Iteration : 430 | Current sparsity: 0.300 | Regularization param.: 1.98e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.10e-04
# Iteration : 435 | Current sparsity: 0.300 | Regularization param.: 1.98e-05 | Desired sparsity: 0.300 | Difference: -0.000 | Beta: 1.17e-04 | Relative change: 5.02e-04
# Desired sparsity reached after 437 iterations!

# %%
x_controlled = fista_controlled.solution
show2D([x_fista, x_controlled], title=["Fixed reg. param.", "Automated reg. param."], fix_range=(0,0.1), size=(10,20));

# %%
import matplotlib.pyplot as plt

N = fista_controlled.iterations[-1]
fig, ax = plt.subplots(2)
ax[0].plot(sparsity_ctrl.sparsity_vals)
ax[0].hlines(sparsity_ctrl.desired_sparsity, xmin=0, xmax=N, colors='r');
ax[0].set_title("Sparsity level")

ax[1].semilogy(sparsity_ctrl.reg_param_vals)
ax[1].set_title("Regularization parameter")
for a in ax.flat:
    a.label_outer()
